# %%
import pandas as pd
import numpy as np
import matplotlib as plt


#matplotlib inline#
df = pd.read_csv('C:/Users/PC/Downloads/Stackoverflow_survey/survey_results_public.csv')
df.head()
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
# 2                      Employed full-time
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

df.columns.tolist()
# Out:
# ['Respondent',
#  'Professional',
#  'ProgramHobby',
#  'Country',
#  'University',
#  'EmploymentStatus',
#  'FormalEducation',
#  'MajorUndergrad',
#  'HomeRemote',
#  'CompanySize',
#  'CompanyType',
#  'YearsProgram',
#  'YearsCodedJob',
#  'YearsCodedJobPast',
#  'DeveloperType',
#  'WebDeveloperType',
#  'MobileDeveloperType',
#  'NonDeveloperType',
#  'CareerSatisfaction',
#  'JobSatisfaction',
#  'ExCoderReturn',
#  'ExCoderNotForMe',
#  'ExCoderBalance',
#  'ExCoder10Years',
#  'ExCoderBelonged',
#  'ExCoderSkills',
#  'ExCoderWillNotCode',
#  'ExCoderActive',
#  'PronounceGIF',
#  'ProblemSolving',
#  'BuildingThings',
#  'LearningNewTech',
#  'BoringDetails',
#  'JobSecurity',
#  'DiversityImportant',
#  'AnnoyingUI',
#  'FriendsDevelopers',
#  'RightWrongWay',
#  'UnderstandComputers',
#  'SeriousWork',
#  'InvestTimeTools',
#  'WorkPayCare',
#  'KinshipDevelopers',
#  'ChallengeMyself',
#  'CompetePeers',
#  'ChangeWorld',
#  'JobSeekingStatus',
#  'HoursPerWeek',
# ...

# %%
df_selectedcolumns = df[['Respondent','Professional','University','FormalEducation', 'EmploymentStatus','YearsCodedJobPast','CareerSatisfaction','Salary']]

df_selectedcolumns.head()

# %%
df_selectedcolumns.dropna(how='any')
# Out:
#        Respondent            Professional      University  \
# 2489         2490  Professional developer              No
# 16772       16773  Professional developer              No
# 25193       25194  Professional developer              No
# 47156       47157  Professional developer  Yes, full-time
# 47810       47811  Professional developer              No
#
#            FormalEducation    EmploymentStatus YearsCodedJobPast  \
# 2489   Professional degree  Employed full-time      1 to 2 years
# 16772    Bachelor's degree  Employed full-time  Less than a year
# 25193      Master's degree  Employed full-time    11 to 12 years
# 47156    Bachelor's degree  Employed full-time  Less than a year
# 47810    Bachelor's degree  Employed full-time      6 to 7 years
#
#        CareerSatisfaction        Salary
# 2489                  7.0  26213.845218
# 16772                 8.0    385.873927
# 25193                 2.0  59139.784946
# 47156                 6.0   1220.862801
# ...

# %% [markdown]
# # 1.  DO YOU NEED TO ATTEND A UNIVERSITY BEFORE BECOMING A  SUCCESSFUL SOFTWARE DEVELOPER?

# %%
# Out:
# [ 2.78959317 -1.14343595  0.39567906  0.97709612  0.53616551  1.71545124]
